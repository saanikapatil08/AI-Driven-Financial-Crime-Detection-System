# %% [markdown]
# # Exploratory Data Analysis - Financial Crime Detection
#
# This notebook explores the transaction and KYC data used by the detection system.

# %%
import sys
from pathlib import Path
sys.path.insert(0, str(Path("../").resolve()))

import pandas as pd
from src.ingestion import load_or_create_data

# %%
# Load data (generates synthetic if not present)
transactions, kyc = load_or_create_data()
print("Transactions shape:", transactions.shape)
print("KYC shape:", kyc.shape)

# %% [markdown]
# ## Transaction Overview

# %%
transactions.head(10)

# %%
transactions.describe()

# %%
# Distribution by transaction type and channel
transactions.groupby(["transaction_type", "channel"]).size().unstack(fill_value=0)

# %% [markdown]
# ## KYC & Customer Segmentation

# %%
kyc.head()

# %%
kyc["segment"].value_counts().plot(kind="bar", title="Customer Segments")

# %% [markdown]
# ## Run Detection Pipeline

# %%
from src.detection import run_detection
entity_risk = run_detection()
entity_risk[entity_risk["high_risk"]].head()
